# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import json

import torch
import torch.nn.functional as F
from torchvision.utils import save_image
import networkx as nx
from matplotlib import pyplot as plt
import matplotlib.patches as patches
from PIL import Image, ImageDraw
import webcolors

from minimal.gen import generate_plan
from minimal.layout import LayoutGraphBuilder, LayoutGraph, NodeType

# %matplotlib inline

# %%
from minimal import sample_graphs
g = sample_graphs.two()

# %%
plt.figure(figsize=(7,3))
g.draw()

# %%
# %%time

plan_masks = generate_plan(g, num_iters=25)
plan_masks
# Out:
# CPU times: user 56.9 s, sys: 9.04 s, total: 1min 5s
# Wall time: 18.5 s
# <PIL.Image.Image image mode=RGB size=256x256>
# <PlanMasks 136746636798176>

# %%
torch.save(plan_masks.state_dict(), "data/plan_masks_02.pth")
